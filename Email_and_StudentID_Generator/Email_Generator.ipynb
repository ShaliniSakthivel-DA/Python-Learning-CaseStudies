# %%
# Email Genereation

full_name = input("Enter Full Name: ")
domain_name = input("Enter Domain Name: ")
print(full_name)
# Out:
# Enter Full Name: SHALINI SAKTHIVEL
# Enter Domain Name: @gmail.com
# SHALINI SAKTHIVEL

# %%
full_name.lower()
# Out:
# 'shalini sakthivel'

# %%
full_name.upper()
# Out:
# 'SHALINI SAKTHIVEL'

# %%
full_name = input("Enter Full Name: ").lower().replace(" ","_")
domain_name = input("Enter Domain Name: ")
print(full_name,domain_name)
# Out:
# Enter Full Name: SHALINI SAKTHIVEL
# Enter Domain Name: @gmail.com
# shalini_sakthivel @gmail.com

# %%
# Concad

print(full_name+domain_name)
# Out:
# shalini_sakthivel@gmail.com

# %%
Email = full_name + domain_name
print(Email)
# Out:
# shalini_sakthivel@gmail.com

# %%
# Student ID card Generator
student_name = input("Enter Student Name: ").upper()
roll_number = int(input("Enter Roll Number: "))
department = input("Enter Deparment: ").upper()
# Out:
# Enter Student Name: Shalini Sakthivel
# Enter Roll Number: 25
# Enter Deparment: Computer Science

# %%
# Slicing

print(student_name[0:5])
print(department[0:5])
# Out:
# SHALI
# COMPU

# %%
# Creating Student ID

Student_ID = student_name + department + str(roll_number)
print(Student_ID)
# Out:
# SHALINI SAKTHIVELCOMPUTER SCIENCE25

# %%
student_id = student_name[0:5] + department[0:5] + str(roll_number)

print(student_id)
# Out:
# SHALICOMPU25

# %%
text = "My Name is Shalini"
sliptname =text.split()
print(sliptname)
# Out:
# ['My', 'Name', 'is', 'Shalini']

# %%
jointext = " ".join(sliptname)
print(jointext)
# Out:
# My Name is Shalini

# %%
name_with_emailid = f"My name is {full_name} and Email id is {Email}"

print(name_with_emailid)
# Out:
# My name is shalini_sakthivel and Email id is shalini_sakthivel@gmail.com
