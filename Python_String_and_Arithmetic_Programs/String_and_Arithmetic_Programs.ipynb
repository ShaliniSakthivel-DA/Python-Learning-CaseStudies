# %%
# 1.Read two numbers and perform all arithmetic operations

Num1 = float(input("Enter the Num1: "))
Num2 = float(input("Enter the Num2: "))

print ("Adding: ", Num1 + Num2 )
print ("Subtraction: ", Num1 - Num2)
print ("Multiplication", Num1 * Num2 )
print ("Division", Num1 / Num2 )
print("Floor Division:", Num1 // Num2)
print("Modulus:", Num1 % Num2)
print("Exponentiation:", Num1 ** Num2)

# 2. Check the data type of the value entered
# Out:
# Enter the Num1: 25.8
# Enter the Num2: 100.7
# Adding:  126.5
# Subtraction:  -74.9
# Multiplication 2598.06
# Division 0.25620655412115195
# Floor Division: 0.0
# Modulus: 25.8
# Exponentiation: 1.4128771142605685e+142

# %%
# 3. Find the length of a string and count the number of words

text = input("Enter the String: ")

print("Length of string: ", len(text))
print("Number of words: ", len(text.split()))
# Out:
# Enter the String: Shalini Sakthivel Data Analyst
# Length of string:  30
# Number of words:  4

# %%
# 4. Count words in a sentence


sentence = input("Enter a sentence: ")

words = sentence.split()
print("Word count:", len(words))
# Out:
# Enter a sentence: Happy World
# Word count: 2
# ['Python', 'is', 'easy']

# %%
# 5. Reverse each word in a sentence

sentence = input("Enter a sentence: ")

words = sentence.split()
reversed_words = [word[::-1] for word in words]

print("Reversed words:", " ".join(reversed_words))
# Out:
# Enter a sentence: Shalini Sakthivel is a Data analyst
# Reversed words: inilahS levihtkaS si a ataD tsylana

# %%
# 6. Check whether a character is a vowel or consonant

character = input("Enter a character: ").lower()

if character in 'aeiou':
    print("It is a vowel")
else:
    print("It is a consonant")
# Out:
# Enter a character: s
# It is a consonant

# %%
# 7. Check if a string is a palindrome

text = input("Enter a string: ")

if text == text[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Enter a string: level
# Palindrome
