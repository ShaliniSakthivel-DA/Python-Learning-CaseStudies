# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaliniSakthivel-DA/Python-Learning-CaseStudies/blob/main/Built_in_Functions_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Common Built-in Functions in Python

# %%
# Lambda Function in Python

# add 2 number

x = 10
y = 20

c = x + y

# lambda arguments : expression
add = lambda x , y : x + y

add(10,20)
# Out:
# 30

# %%
#to square a number
square = lambda x : x * x
print(square(5))
print(square(6))
# Out:
# 25
# 36

# %% [markdown]
# # Lambda Function with Iterables

# %%
# x = list(map(int,input("Enter the list:").split(",")))
# print(x)

# map(operations, iterables)
a =["1","2","3","4"]

x =list(map(int,a))
x
# Out:
# [1, 2, 3, 4]

# %%
x = [10, 2, 4, 6, 7, 8, 9,9]
square = list(map(lambda a : a * a, x))
print(square)
# Out:
# [100, 4, 16, 36, 49, 64, 81, 81]

# %%
x = [4.124,5.66,4.78,3.78]

num = list(map(lambda a: round(a,1), x))

print(num)
# Out:
# [4.1, 5.7, 4.8, 3.8]

# %% [markdown]
# # Lambda with filter()

# %%
x = [10, 2, 4, 6, 7, 8, 9,9]


even_list = list(filter(lambda x :x % 2 == 0,x))
print(even_list)

odd_list = list(filter(lambda x :x % 2 != 0,x))
print(odd_list)
# Out:
# [10, 2, 4, 6, 8]
# [7, 9, 9]

# %% [markdown]
# # Case Study – Employee Salary Analysis
#
# Instructions
#
# Create a list called salary Store employee salaries inside the list
#
# Use Built-in Functions to:
#
# Find maximum salary
#
# Find minimum salary
#
# Find total salary
#
# Find number of employees using len()
#
# Use lambda with map() to: Increase each salary by 10%
#
# Use lambda with filter() to: Display salaries greater than 50000
#
# Display:
#
# Original salary list
#
# Updated salary list
#
# High salary list
#
# Maximum salary
#
# Minimum salary
#
# Total salary

# %%
# Employee Salary Analysis

# Create salary list
salary = [25000, 45000, 55000, 70000, 48000, 90000]

# Display original salary list
print("Original Salary List:", salary)

# Built-in Functions
max_salary = max(salary)
min_salary = min(salary)
total_salary = sum(salary)
employee_count = len(salary)

# Increase each salary by 10% using lambda and map()
updated_salary = list(map(lambda x: x + (x * 0.10), salary))

# Filter salaries greater than 50000 using lambda and filter()
high_salary = list(filter(lambda x: x > 50000, updated_salary))

# Display Results
print("\nUpdated Salary List:", updated_salary)
print("High Salary List (>50000):", high_salary)

print("\nMaximum Salary:", max_salary)
print("Minimum Salary:", min_salary)
print("Total Salary:", total_salary)
print("Number of Employees:", employee_count)
# Out:
# Original Salary List: [25000, 45000, 55000, 70000, 48000, 90000]
#
# Updated Salary List: [27500.0, 49500.0, 60500.0, 77000.0, 52800.0, 99000.0]
# High Salary List (>50000): [60500.0, 77000.0, 52800.0, 99000.0]
#
# Maximum Salary: 90000
# Minimum Salary: 25000
# Total Salary: 333000
# Number of Employees: 6
